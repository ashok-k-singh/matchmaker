# %% [markdown]
# # Load to AWS the matchdata table used to train the model

# %% [markdown]
# ## Load dependencies and import data from S3 bucket

# %%
import pandas as pd

# %%
df = pd.read_csv('https://aws-matchmaker-bucket.s3-us-west-2.amazonaws.com/SpeedDatingPreprocessed.csv')

# %%
df.head()
# Out:
#   couple_id  f_age  f_imprace  f_attr  f_sinc  f_intel  f_fun  f_amb  f_race  \
# 0    f1-m11   21.0        2.0     6.0     9.0      7.0    7.0    6.0     4.0
# 1    f1-m12   21.0        2.0     7.0     8.0      7.0    8.0    5.0     4.0
# 2    f1-m13   21.0        2.0     5.0     8.0      9.0    8.0    5.0     4.0
# 3    f1-m14   21.0        2.0     7.0     6.0      8.0    7.0    6.0     4.0
# 4    f1-m15   21.0        2.0     5.0     6.0      7.0    7.0    6.0     4.0
#
#    f_intrace  ...  m_imprace  m_attr  m_sinc  m_intel  m_fun  m_amb  m_race  \
# 0        0.0  ...        7.0     6.0     8.0      8.0    8.0    8.0     2.0
# 1        0.0  ...        1.0     7.0     8.0     10.0    7.0    7.0     2.0
# 2        2.0  ...        3.0    10.0    10.0     10.0   10.0   10.0     4.0
# 3        0.0  ...        1.0     7.0     8.0      9.0    8.0    9.0     2.0
# 4        0.0  ...        3.0     8.0     7.0      9.0    6.0    9.0     3.0
#
#    samerace  match  m_intrace
# ...

# %% [markdown]
# ## Connect to AWS RDS database and load the table

# %% [markdown]
# Predecessor tasks: create the database via AWS Management Console.

# %%
from sqlalchemy import create_engine
import config
engine = create_engine(f"postgresql+psycopg2://{config.pguser}:{config.pgpassword}@{config.pghost}:{config.pgport}/{config.pgdatabase}")

# %% [markdown]
# Predecessor tasks: create table via PGAdmin

# %%
df.to_sql('matchdata', engine, if_exists='append',index=False)

# %% [markdown]
# Verify!

# %%
test_df = pd.read_sql('matchdata',engine)
test_df
# Out:
#       couple_id  f_age  f_imprace  f_attr  f_sinc  f_intel  f_fun  f_amb  \
# 0        f1-m11   21.0        2.0     6.0     9.0      7.0    7.0    6.0
# 1        f1-m12   21.0        2.0     7.0     8.0      7.0    8.0    5.0
# 2        f1-m13   21.0        2.0     5.0     8.0      9.0    8.0    5.0
# 3        f1-m14   21.0        2.0     7.0     6.0      8.0    7.0    6.0
# 4        f1-m15   21.0        2.0     5.0     6.0      7.0    7.0    6.0
# 5        f1-m16   21.0        2.0     4.0     9.0      7.0    4.0    6.0
# 6        f1-m17   21.0        2.0     7.0     6.0      7.0    4.0    6.0
# 7        f1-m18   21.0        2.0     4.0     9.0      7.0    6.0    5.0
# 8        f1-m19   21.0        2.0     7.0     6.0      8.0    9.0    8.0
# 9        f1-m20   21.0        2.0     5.0     6.0      6.0    8.0   10.0
# 10       f2-m11   24.0        2.0     5.0     7.0      8.0    4.0    6.0
# 11       f2-m12   24.0        2.0     8.0     5.0      6.0    6.0    9.0
# ...
